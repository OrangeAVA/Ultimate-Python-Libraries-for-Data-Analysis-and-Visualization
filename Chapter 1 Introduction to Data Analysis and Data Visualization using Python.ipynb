# %%
import pandas as pd

# %%
# Load the IPL dataset
df = pd.read_csv('IPL_Ball_by_Ball_2008_2022.csv')

# %%
# Display the first few rows of the dataset
df.head(10)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# 5  1312200        1      0           6  YBK Jaiswal  Mohammed Shami
# 6  1312200        1      1           1   JC Buttler      Yash Dayal
# 7  1312200        1      1           2   JC Buttler      Yash Dayal
# 8  1312200        1      1           3   JC Buttler      Yash Dayal
# 9  1312200        1      1           4   JC Buttler      Yash Dayal
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# ...

# %%
df.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
num_rows, num_cols = df.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_cols)
# Out:
# Number of rows: 225954
# Number of columns: 17

# %%
data_types = df.dtypes
print(data_types)
# Out:
# ID                    int64
# innings               int64
# overs                 int64
# ballnumber            int64
# batter               object
# bowler               object
# non-striker          object
# extra_type           object
# batsman_run           int64
# extras_run            int64
# total_run             int64
# non_boundary          int64
# isWicketDelivery      int64
# player_out           object
# kind                 object
# fielders_involved    object
# BattingTeam          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 225954 non-null  int64
#  1   innings            225954 non-null  int64
#  2   overs              225954 non-null  int64
#  3   ballnumber         225954 non-null  int64
#  4   batter             225954 non-null  object
#  5   bowler             225954 non-null  object
#  6   non-striker        225954 non-null  object
#  7   extra_type         12049 non-null   object
#  8   batsman_run        225954 non-null  int64
#  9   extras_run         225954 non-null  int64
#  10  total_run          225954 non-null  int64
#  11  non_boundary       225954 non-null  int64
#  12  isWicketDelivery   225954 non-null  int64
#  13  player_out         11151 non-null   object
#  14  kind               11151 non-null   object
# ...

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# ID                        0
# innings                   0
# overs                     0
# ballnumber                0
# batter                    0
# bowler                    0
# non-striker               0
# extra_type           213905
# batsman_run               0
# extras_run                0
# total_run                 0
# non_boundary              0
# isWicketDelivery          0
# player_out           214803
# kind                 214803
# fielders_involved    217966
# BattingTeam               0
# dtype: int64

# %%
df.describe()
# Out:
#                  ID        innings          overs     ballnumber  \
# count  2.259540e+05  225954.000000  225954.000000  225954.000000
# mean   8.320470e+05       1.483868       9.185679       3.619750
# std    3.379542e+05       0.503104       5.681797       1.810633
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.012620e+05       1.000000       4.000000       2.000000
# 50%    8.297370e+05       1.000000       9.000000       4.000000
# 75%    1.178395e+06       2.000000      14.000000       5.000000
# max    1.312200e+06       6.000000      19.000000      10.000000
#
#          batsman_run     extras_run     total_run   non_boundary  \
# count  225954.000000  225954.000000  225954.00000  225954.000000
# mean        1.243523       0.066907       1.31043       0.000093
# std         1.618166       0.341470       1.60605       0.009640
# min         0.000000       0.000000       0.00000       0.000000
# ...

# %%
df['non_boundary'].value_counts() #Mostly runs scored by the boundaries
# Out:
# non_boundary
# 0    225933
# 1        21
# Name: count, dtype: int64

# %%
df['isWicketDelivery'].value_counts() #Mostly there are non wicket deliveries
# Out:
# isWicketDelivery
# 0    214803
# 1     11151
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Filter data for player scores
player_scores = df['batsman_run']

# Plot histogram
plt.hist(player_scores, bins=20, edgecolor='black')
plt.xlabel('Player Scores')
plt.ylabel('Frequency')
plt.title('Distribution of Player Scores')
plt.show()

# %%
import seaborn as sns

# Group data by batsman and calculate total runs
batsman_runs = df.groupby('batter')['batsman_run'].sum().reset_index()

# Sort data by total runs
batsman_runs = batsman_runs.sort_values(by='batsman_run', ascending=False).head(10)

# Create bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='batsman_run', y='batter', data=batsman_runs, palette='viridis')
plt.xlabel('Total Runs')
plt.ylabel('Batsman')
plt.title('Top 10 Batsmen by Total Runs')
plt.show()

# %%
# Get value counts for the categories
category_counts = df['kind'].value_counts()

# Extract the top 3 categories
top_categories = category_counts.head(4)

# %%
#dismissals = df['kind'].value_counts()

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_categories, labels=top_categories.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Dismissal Types')
plt.axis('equal')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 225954 non-null  int64
#  1   innings            225954 non-null  int64
#  2   overs              225954 non-null  int64
#  3   ballnumber         225954 non-null  int64
#  4   batter             225954 non-null  object
#  5   bowler             225954 non-null  object
#  6   non-striker        225954 non-null  object
#  7   extra_type         12049 non-null   object
#  8   batsman_run        225954 non-null  int64
#  9   extras_run         225954 non-null  int64
#  10  total_run          225954 non-null  int64
#  11  non_boundary       225954 non-null  int64
#  12  isWicketDelivery   225954 non-null  int64
#  13  player_out         11151 non-null   object
#  14  kind               11151 non-null   object
# ...

# %%
'''
correlation_matrix = df.corr()

# Create heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
'''
# Out:
# "\ncorrelation_matrix = df.corr()\n\n# Create heatmap\nplt.figure(figsize=(10, 8))\nsns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')\nplt.title('Correlation Matrix')\nplt.show()\n"

# %%
df_matches = pd.read_csv('IPL_Matches_2008_2022.csv')

# %%
df_matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
#What is the percentage of wins of each team?

# Count the number of wins for each team
team_wins = df_matches["WinningTeam"].value_counts()

# Calculate the percentage of wins for each team
total_matches = df_matches["Team1"].nunique() + df_matches["Team2"].nunique()
team_win_percentage = (team_wins / total_matches) * 100

print("Percentage of wins for each team:")
print(team_win_percentage)
# Out:
# Percentage of wins for each team:
# Mumbai Indians                 363.888889
# Chennai Super Kings            336.111111
# Kolkata Knight Riders          316.666667
# Royal Challengers Bangalore    302.777778
# Rajasthan Royals               266.666667
# Kings XI Punjab                244.444444
# Sunrisers Hyderabad            208.333333
# Delhi Daredevils               186.111111
# Delhi Capitals                 100.000000
# Deccan Chargers                 80.555556
# Gujarat Lions                   36.111111
# Punjab Kings                    36.111111
# Pune Warriors                   33.333333
# Gujarat Titans                  33.333333
# Rising Pune Supergiant          27.777778
# Lucknow Super Giants            25.000000
# Kochi Tuskers Kerala            16.666667
# Rising Pune Supergiants         13.888889
# Name: WinningTeam, dtype: float64

# %%
#Which venue results in a win for the batting first team and vice versa?

# Group the data by venue and batting first team
venue_wins_batting_first = df[df["innings"] == df_matches["WinningTeam"]]["City"].value_counts()

# Group the data by venue and batting second team
venue_wins_batting_second = data[data["innings2"] == data["winner"]]["venue"].value_counts()

print("Venues with more wins for batting first team:")
print(venue_wins_batting_first)

print("Venues with more wins for batting second team:")
print(venue_wins_batting_second)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 4
#       1 #Which venue results in a win for the batting first team and vice versa?
#       2
#       3 # Group the data by venue and batting first team
# ----> 4 venue_wins_batting_first = df[df["innings"] == df_matches["WinningTeam"]]["City"].value_counts()
#       6 # Group the data by venue and batting second team
#       7 venue_wins_batting_second = data[data["innings2"] == data["winner"]]["venue"].value_counts()
#
# File D:\Anaconda_1\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File D:\Anaconda_1\lib\site-packages\pandas\core\arraylike.py:42, in OpsMixin.__eq__(self, other)
# ...

# %%
df["innings"].value_counts()

# %%
#Who is the most consistent batsman and bowler in each team and also in the entire league


# Group the data by batsman and calculate average runs per match
batsman_average_runs = df.groupby("batter")["batsman_run"].mean()

# Group the data by bowler and calculate average wickets per match
bowler_average_wickets = df.groupby("bowler")["isWicketDelivery"].mean()

print("Most consistent batsman in each team:")
for team in df_matches["Team1"].unique():
    team_batsmen = data[data["team1"] == team]["batsman"].unique()
    team_consistent_batsman = batsman_average_runs[batsman_average_runs.index.isin(team_batsmen)]
    print(f"{team}: {team_consistent_batsman.idxmax()}")

print("Most consistent bowler in each team:")
for team in data["team1"].unique():
    team_bowlers = data[data["team1"] == team]["bowler"].unique()
    team_consistent_bowler = bowler_average_wickets[bowler_average_wickets.index.isin(team_bowlers)]
    print(f"{team}: {team_consistent_bowler.idxmax()}")

print("Most consistent batsman in the entire league:")
print(batsman_average_runs.idxmax())

print("Most consistent bowler in the entire league:")
print(bowler_average_wickets.idxmax())
``

# %%
#Who wins the most player of the matches in the tournament?

# Count the number of player of the match awards for each player
player_of_match = data["player_of_match"].value_counts()

print("Player with the most player of the match awards:")
print(player_of_match.idxmax())

# %%
#Most valuable player of the season


# Group the data by season and player of the match
season_player_of_match = data.groupby("season")["player_of_match"].value_counts()

print("Most valuable player of each season:")
for season in data["season"].unique():
    season_most_valuable_player = season_player_of_match.loc[season].idxmax()
    print(f"Season {season}: {season_most_valuable_player[1]}")
