# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\1508\AppData\Roaming\Python\Python310\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Create a DataFrame
df = pd.read_excel('GDP data.xlsx')

# %%
df.head(5)
# Out:
#      #       Country  GDP (nominal, 2022)             GDP  GDP (growth)  \
# 0   17  Saudi Arabia        1108150000000  1.108 trillion        0.0874
# 1  167       Comoros           1242519407    1.24 billion        0.0239
# 2  166       Grenada           1256413185    1.26 billion        0.0580
# 3   16     Indonesia        1319100000000  1.319 trillion        0.0531
# 4   15         Spain        1397510000000  1.398 trillion        0.0545
#
#    Population (2022)  GDP per capita  Share of World GDP
# 0           36408820           30436              0.0110
# 1             836774            1485              0.0000
# 2             125438           10016              0.0000
# 3          275501339            4788              0.0131
# 4           47558630           29385              0.0139

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   #                    177 non-null    int64
#  1   Country              177 non-null    object
#  2   GDP (nominal, 2022)  177 non-null    int64
#  3   GDP                  177 non-null    object
#  4   GDP (growth)         177 non-null    float64
#  5   Population (2022)    177 non-null    int64
#  6   GDP per capita       177 non-null    int64
#  7   Share of World GDP   177 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 11.2+ KB
# None

# %%
df = df.drop(['GDP'], axis=1)

# %%
df.head(5)
# Out:
#      #       Country  GDP (nominal, 2022)  GDP (growth)  Population (2022)  \
# 0   17  Saudi Arabia        1108150000000        0.0874           36408820
# 1  167       Comoros           1242519407        0.0239             836774
# 2  166       Grenada           1256413185        0.0580             125438
# 3   16     Indonesia        1319100000000        0.0531          275501339
# 4   15         Spain        1397510000000        0.0545           47558630
#
#    GDP per capita  Share of World GDP
# 0           30436              0.0110
# 1            1485              0.0000
# 2           10016              0.0000
# 3            4788              0.0131
# 4           29385              0.0139

# %%
print(df.isnull().sum())
# Out:
# #                      0
# Country                0
# GDP (nominal, 2022)    0
# GDP (growth)           0
# Population (2022)      0
# GDP per capita         0
# Share of World GDP     0
# dtype: int64

# %%
print(df.describe())
# Out:
#                 #  GDP (nominal, 2022)  GDP (growth)  Population (2022)  \
# count  177.000000         1.770000e+02    177.000000       1.770000e+02
# mean    89.000000         5.588979e+11      0.041038       4.368887e+07
# std     51.239633         2.404638e+12      0.066641       1.560540e+08
# min      1.000000         6.034939e+07     -0.291000       1.131200e+04
# 25%     45.000000         1.356313e+10      0.023900       2.388992e+06
# 50%     89.000000         4.575234e+10      0.039300       9.038309e+06
# 75%    133.000000         3.010250e+11      0.058100       3.347587e+07
# max    177.000000         2.546270e+13      0.578000       1.425887e+09
#
#        GDP per capita  Share of World GDP
# count      177.000000          177.000000
# mean     16825.977401            0.005554
# std      23072.367011            0.023913
# min        238.000000            0.000000
# 25%       2322.000000            0.000100
# 50%       6728.000000            0.000500
# ...

# %%
sns.pairplot(df)
plt.show()
# Out:
# C:\Users\1508\AppData\Local\anaconda30\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\1508\AppData\Local\anaconda30\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\1508\AppData\Local\anaconda30\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df.boxplot(figsize=(15,10))
plt.show()

# %%
df.columns
# Out:
# Index(['#', 'Country', 'GDP (nominal, 2022)', 'GDP (growth)',
#        'Population (2022)', 'GDP per capita', 'Share of World GDP'],
#       dtype='object')

# %%
columns_of_interest = ['GDP (nominal, 2022)', 'GDP (growth)', 'Population (2022)', 'GDP per capita', 'Share of World GDP']
corr_matrix = df[columns_of_interest].corr()

sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
# GDP distribution
plt.figure(figsize=(12, 6))
sns.histplot(df['GDP (nominal, 2022)'], bins=30, kde=True)
plt.title('Distribution of GDP (Nominal) in 2022')
plt.xlabel('GDP (Nominal) in Billion USD')
plt.show()
# Out:
# C:\Users\1508\AppData\Local\anaconda30\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Top 10 countries by GDP
top_gdp_countries = df.sort_values(by='GDP (nominal, 2022)', ascending=False).head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x='Country', y='GDP (nominal, 2022)', data=top_gdp_countries, palette='viridis')
plt.title('Top 10 Countries by GDP (Nominal) in 2022')
plt.ylabel('GDP (Nominal) in Billion USD')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Bottom 10 countries by GDP
top_gdp_countries = df.sort_values(by='GDP (nominal, 2022)', ascending=True).head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x='Country', y='GDP (nominal, 2022)', data=top_gdp_countries, palette='viridis')
plt.title('Top 10 Countries by GDP (Nominal) in 2022')
plt.ylabel('GDP (Nominal) in Billion USD')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Assuming df is the dataframe with the GDP and Population data
df = df.sort_values('GDP (nominal, 2022)', ascending=False)
top_10_countries = df.head(10)

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Population (2022)', y='GDP (nominal, 2022)', data=top_10_countries, hue='Country', palette='Set1', alpha=0.7)
plt.title('Top 10 Countries with the Most Nominal GDP in 2022')
plt.xlabel('Population')
plt.ylabel('GDP (Nominal) in Billion USD')
plt.xscale('log') # Log scale for better visualization
plt.yscale('log')
plt.show()

# %%
# Displaying the bottom 10 countries with the lowest nominal GDP
bottom_10_countries = df.nsmallest(10, 'GDP (nominal, 2022)')
print(bottom_10_countries[['Country', 'GDP (nominal, 2022)']])

# Visualizing the relationship between GDP and Population for the bottom 10 countries
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Population (2022)', y='GDP (nominal, 2022)', data=bottom_10_countries, hue='Country', palette='Set1', alpha=0.7)
plt.title('Bottom 10 Countries with the Least Nominal GDP in 2022')
plt.xlabel('Population')
plt.ylabel('GDP (Nominal) in Billion USD')
plt.xscale('log') # Log scale for better visualization
plt.yscale('log')
plt.show()
# Out:
#                       Country  GDP (nominal, 2022)
# 148                    Tuvalu             60349391
# 73                   Kiribati            223352943
# 86           Marshall Islands            279667900
# 121                Micronesia            427094119
# 140       Sao Tome & Principe            546680342
# 149                  Dominica            612048148
# 169                     Samoa            832421565
# 172  St. Vincent & Grenadines            948558503
# 174       Saint Kitts & Nevis            961563259
# 175                   Vanuatu            983582865

# %%
# Boxplots for GDP and Population across countries
plt.figure(figsize=(15, 10))
sns.boxplot(data=bottom_10_countries, x='Country', y='GDP (nominal, 2022)', orient='v')
plt.title('Boxplot for GDP across countries')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['Population (2022)'], df['GDP per capita'])
plt.title('GDP per capita vs Population (2022)')
plt.xlabel('Population (2022)')
plt.ylabel('GDP per capita')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Population (2022)', y='GDP per capita')
plt.title('GDP per capita vs Population (2022)')
plt.xlabel('Population (2022)')
plt.ylabel('GDP per capita')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Population (2022)', y='Share of World GDP')
plt.title('Share of World GDP vs Population (2022)')
plt.xlabel('Population (2022)')
plt.ylabel('Share of World GDP')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='GDP per capita', y='GDP (growth)')
plt.title('GDP (growth) vs GDP per capita')
plt.xlabel('GDP per capita')
plt.ylabel('GDP (growth)')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='GDP per capita', y='Share of World GDP')
plt.title('Share of World GDP vs GDP per capita')
plt.xlabel('GDP per capita')
plt.ylabel('Share of World GDP')
plt.show()

# %%
# Sorting the dataframe by GDP (nominal, 2022) to get the top 10 countries
top_countries = df.sort_values(by='GDP (nominal, 2022)', ascending=False).head(10)

# Plotting the pie chart for the % share of World GDP of the top 10 countries
plt.figure(figsize=(10, 10))
plt.pie(top_countries['Share of World GDP'], labels=top_countries['Country'], autopct='%1.1f%%', startangle=140)
plt.title('Top 10 Countries by % Share of World GDP')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Population (2022)', y='GDP (growth)')
plt.title('GDP (growth) vs Population (2022)')
plt.xlabel('Population (2022)')
plt.ylabel('GDP (growth)')
plt.show()

# %%
df.columns
# Out:
# Index(['#', 'Country', 'GDP (nominal, 2022)', 'GDP (growth)',
#        'Population (2022)', 'GDP per capita', 'Share of World GDP'],
#       dtype='object')

# %%
from scipy import stats
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Variable importance
model = LinearRegression()
model.fit(df[['Population (2022)']], df['GDP per capita'])

print('R-squared:', model.score(df[['Population (2022)']], df['GDP per capita']))
# Out:
# R-squared: 0.0024223163260445046

# %%
# Hypothesis testing
alpha = 0.05

# Shapiro-Wilk normality test
shapiro_test = stats.shapiro(df['GDP per capita'])

print('Shapiro-Wilk normality test:', shapiro_test)

if shapiro_test[1] > alpha:
    print('GDP per capita follows normal distribution')
else:
    print('GDP per capita does not follow normal distribution')
# Out:
# Shapiro-Wilk normality test: ShapiroResult(statistic=0.704981803894043, pvalue=2.031437959347131e-17)
# GDP per capita does not follow normal distribution

# %%
# t-test for the difference in means
t_test = stats.ttest_ind(df['GDP per capita'][df['Country'] == 'USA'], 
                          df['GDP per capita'][df['Country'] == 'India'])

print('t-test:', t_test)

if t_test[1] > alpha:
    print('No significant difference in means')
else:
    print('Significant difference in means')
# Out:
# t-test: TtestResult(statistic=nan, pvalue=nan, df=nan)
# Significant difference in means

# %%
# ANOVA test for checking if country affects GDP per capita
anova_test = stats.f_oneway(df['GDP per capita'][df['Country'] == 'USA'], 
                             df['GDP per capita'][df['Country'] == 'China'], 
                             df['GDP per capita'][df['Country'] == 'India'])

print('ANOVA test:', anova_test)

if anova_test[1] > alpha:
    print('Country does not affect GDP per capita')
else:
    print('Country affects GDP per capita')
# Out:
# ANOVA test: F_onewayResult(statistic=nan, pvalue=nan)
# Country affects GDP per capita
# C:\Users\1508\AppData\Local\anaconda30\lib\site-packages\scipy\stats\_stats_py.py:4133: DegenerateDataWarning: at least one input has length 0
#   warnings.warn(stats.DegenerateDataWarning('at least one input '

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Assuming 'data' is a pandas dataframe containing your data
X = df[['Population (2022)']]
y = df['GDP per capita']

# Apply PolynomialFeatures
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.2, random_state=0)

# Apply linear regression
model = LinearRegression()
model.fit(X_train, y_train)

# Predict and evaluate model performance
y_pred = model.predict(X_test)
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('R2 Score:', r2_score(y_test, y_pred))

# Visualize the results
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(poly.fit_transform(X)), color='red')
plt.title('Population (2022) vs GDP per capita')
plt.xlabel('Population (2022)')
plt.ylabel('GDP per capita')
plt.show()
# Out:
# Mean Squared Error: 471826266.70010966
# R2 Score: 0.007794913994695896

# %%
# Calculate MSE and RMSE
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print('Mean Squared Error:', mse)
print('Root Mean Squared Error:', rmse)
# Out:
# Mean Squared Error: 471826266.70010966
# Root Mean Squared Error: 21721.56225275037

# %% [markdown]
# # Mito Low Code tool

# %%
# !python -m pip install mitosheet
# Out:
# ...
#      ---------------------------------------- 4.9/4.9 MB 1.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 153.2/153.2 kB 2.3 MB/s eta 0:00:00
# ...
#   Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# ...
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# ...

# %%
# !python -m jupyter nbextension install --py --user mitosheet
# Out:
# Installing C:\Users\1508\AppData\Local\anaconda30\lib\site-packages\mitosheet\nbextension -> mitosheet
# Up to date: C:\Users\1508\AppData\Roaming\jupyter\nbextensions\mitosheet\066dddb9220086e56a27a6c6986d0546.svg
# Up to date: C:\Users\1508\AppData\Roaming\jupyter\nbextensions\mitosheet\06de3f6f47040a96e1b75f57ff2be41f.svg
# Up to date: C:\Users\1508\AppData\Roaming\jupyter\nbextensions\mitosheet\084b59edab2415645e3e81e6a715dc08.svg
# Up to date: C:\Users\1508\AppData\Roaming\jupyter\nbextensions\mitosheet\09f3e4106c73962f016e29bf9aa511c6.svg
# Up to date: C:\Users\1508\AppData\Roaming\jupyter\nbextensions\mitosheet\0b22fba7dd1dd7b9b2f5cc46d4e2343c.svg
# Up to date: C:\Users\1508\AppData\Roaming\jupyter\nbextensions\mitosheet\0f1d43ae124df30d5d8ed5c5c99d3b5e.svg
# Up to date: C:\Users\1508\AppData\Roaming\jupyter\nbextensions\mitosheet\0fc6ae9cf3db8ad62b1ce50985ae4997.svg
# ...

# %%
# !python -m jupyter nbextension enable --py --user mitosheet
# Out:
# Enabling notebook extension mitosheet/extension...
#       - Validating: ok

# %%
import mitosheet

# %%
mitosheet.sheet(analysis_to_replay="id-xrfnfteibq")
# Out:
# <div id=dc90e24c-44d2-4e0e-be4e-2d6495d9d4ee class="mito-container-container">
#         <script>
# ...

# %%
from mitosheet.public.v3 import *; # Analysis Name:id-xrfnfteibq;
import pandas as pd

# Imported Sheet2 from GDP data.xlsx
sheet_df_dictonary = pd.read_excel(r'GDP data.xlsx', engine='openpyxl', sheet_name=[
    'Sheet2'
], skiprows=0)
Sheet2 = sheet_df_dictonary['Sheet2']

# %% [markdown]
# # PivotTableJS

# %%
# !pip install pivottablejs
# Out:
# ...
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# ...

# %%
# Create a DataFrame
df = pd.read_excel('GDP data.xlsx')

# %%
from pivottablejs import pivot_ui

pivot_ui(df)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Drawdata

# %%
# !python -m pip install drawdata
# Out:
# ...
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)

# %%
from drawdata import draw_scatter

draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # PyGWalker

# %%
# !pip install pygwalker
# Out:
# ...
#      ---------------------------------------- 1.5/1.5 MB 4.3 MB/s eta 0:00:00
# ...
#      ------------------------------------- 957.8/957.8 kB 12.1 MB/s eta 0:00:00
# ...
#      ------------------------------------- 339.4/339.4 kB 10.3 MB/s eta 0:00:00
# ...
#      --------------------------------------- 10.3/10.3 MB 12.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.8/4.8 MB 4.2 MB/s eta 0:00:00
# ...
#   Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# ...
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
#     WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# ...

# %%
import pygwalker as pyg

# %%
walker = pyg.walk(df)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-0" style="height: auto">\n    <head>\n        <meta http-equiv="Con…
