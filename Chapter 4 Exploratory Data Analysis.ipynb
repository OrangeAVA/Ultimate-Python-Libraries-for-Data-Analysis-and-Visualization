# %%
import pandas as pd

# %%
df= pd.read_csv('2024 QS World University Rankings 1.1 (For qs.com).csv')

# %%
df.head()
# Out:
#       2024 RANK      2023 RANK                              Institution Name  \
# 0  rank display  rank display2                                   institution
# 1             1              1  Massachusetts Institute of Technology (MIT)
# 2             2              2                       University of Cambridge
# 3             3              4                          University of Oxford
# 4             4              5                            Harvard University
#
#     Country Code         Country  SIZE  FOCUS      RES.       AGE  STATUS  \
# 0  location code        location  size  focus  research  age band  status
# 1             US   United States     M     CO        VH         5       B
# 2             UK  United Kingdom     L     FC        VH         5       A
# 3             UK  United Kingdom     L     FC        VH         5       A
# 4             US   United States     L     FC        VH         5       B
#
# ...

# %%
df = df.drop(index=0)

# %%
df.head()
# Out:
#   2024 RANK 2023 RANK                              Institution Name  \
# 1         1         1  Massachusetts Institute of Technology (MIT)
# 2         2         2                       University of Cambridge
# 3         3         4                          University of Oxford
# 4         4         5                            Harvard University
# 5         5         3                           Stanford University
#
#   Country Code         Country SIZE FOCUS RES. AGE STATUS  ...  \
# 1           US   United States    M    CO   VH   5      B  ...
# 2           UK  United Kingdom    L    FC   VH   5      A  ...
# 3           UK  United Kingdom    L    FC   VH   5      A  ...
# 4           US   United States    L    FC   VH   5      B  ...
# 5           US   United States    L    FC   VH   5      B  ...
#
#   International Faculty Rank International Students Score  \
# 1                         56                         88.2
# ...

# %%
df.columns
# Out:
# Index(['2024 RANK', '2023 RANK', 'Institution Name', 'Country Code', 'Country',
#        'SIZE', 'FOCUS', 'RES.', 'AGE', 'STATUS', 'Academic Reputation Score',
#        'Academic Reputation Rank', 'Employer Reputation Score',
#        'Employer Reputation Rank', 'Faculty Student Score',
#        'Faculty Student Rank', 'Citations per Faculty Score',
#        'Citations per Faculty Rank', 'International Faculty Score',
#        'International Faculty Rank', 'International Students Score',
#        'International Students Rank', 'International Research Network Score',
#        'International Research Network Rank', 'Employment Outcomes Score',
#        'Employment Outcomes Rank', 'Sustainability Score',
#        'Sustainability Rank', 'Overall SCORE'],
#       dtype='object')

# %%
df['Overall SCORE'].describe()
# Out:
# count     1497
# unique     350
# top          -
# freq       895
# Name: Overall SCORE, dtype: object

# %%
df.describe()
# Out:
#         2024 RANK 2023 RANK                              Institution Name  \
# count        1497      1415                                          1497
# unique        379       333                                          1497
# top     1201-1400  801-1000  Massachusetts Institute of Technology (MIT)
# freq          206       204                                             1
#
#        Country Code        Country  SIZE FOCUS  RES.   AGE STATUS  ...  \
# count          1497           1497  1474  1496  1410  1471   1455  ...
# unique          104            104     4     4     4     5      3  ...
# top              US  United States     L    FC    VH     5      A  ...
# freq            199            199   688   595   922   543   1157  ...
#
#        International Faculty Rank International Students Score  \
# count                        1371                         1417
# unique                        683                          523
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1497 entries, 1 to 1497
# Data columns (total 29 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   2024 RANK                             1497 non-null   object
#  1   2023 RANK                             1415 non-null   object
#  2   Institution Name                      1497 non-null   object
#  3   Country Code                          1497 non-null   object
#  4   Country                               1497 non-null   object
#  5   SIZE                                  1474 non-null   object
#  6   FOCUS                                 1496 non-null   object
#  7   RES.                                  1410 non-null   object
#  8   AGE                                   1471 non-null   object
#  9   STATUS                                1455 non-null   object
#  10  Academic Reputation Score             1497 non-null   object
# ...

# %%
df['Sustainability Score '] = df['Sustainability Score'].astype(float)

# %%
df['Sustainability Score '].mean()
# Out:
# 25.429348604151752

# %%
df['Sustainability Score '].median()
# Out:
# 8.4

# %%
df['Sustainability Score '].mode()
# Out:
# 0    1.0
# Name: Sustainability Score , dtype: float64

# %%
df['Sustainability Score '].describe()
# Out:
# count    1397.000000
# mean       25.429349
# std        31.014888
# min         1.000000
# 25%         1.400000
# 50%         8.400000
# 75%        42.600000
# max       100.000000
# Name: Sustainability Score , dtype: float64

# %%
import seaborn as sns

# %%
sns.kdeplot(df['Sustainability Score '])
# Out:
# C:\Users\1508\AppData\Local\anaconda30\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Sustainability Score ', ylabel='Density'>

# %%
sns.ecdfplot(df['Sustainability Score '])
# Out:
# C:\Users\1508\AppData\Local\anaconda30\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Sustainability Score ', ylabel='Proportion'>

# %%
sns.histplot(df['Sustainability Score '])
# Out:
# C:\Users\1508\AppData\Local\anaconda30\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Sustainability Score ', ylabel='Count'>

# %% [markdown]
# QQ Plot: A Q-Q (quantile-quantile) plot is a probability plot for comparing two probability distributions by plotting their quantiles against each other.

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

stats.probplot(df['Sustainability Score '], dist="norm", plot=plt)
plt.show()

# %% [markdown]
# Rug Plot: A rug plot is a plot with a one-dimensional set of observations, represented as marks along an axis. It is often used in combination with a KDE.

# %%
sns.rugplot(df['Sustainability Score '])
# Out:
# C:\Users\1508\AppData\Local\anaconda30\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Sustainability Score '>

# %% [markdown]
# # Correlation Analysis

# %%
#url = 'https://www.kaggle.com/datasets/vikasukani/diabetes-data-set?select=diabetes-dataset.csv'
import pandas as pd
# Load the dataset
df = pd.read_csv('diabetes-dataset.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
print(df.dtypes)
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# Compute the correlation matrix
corr_matrix = df.corr()

# %%
# Compute the Spearman correlation matrix
spearman_corr_matrix = df.corr(method='spearman')
print("\nSpearman Correlation Matrix: ")
spearman_corr_matrix
# Out:
# Spearman Correlation Matrix:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.113963       0.177586      -0.072205
# Glucose                      0.113963  1.000000       0.218068       0.072516
# BloodPressure                0.177586  0.218068       1.000000       0.147944
# SkinThickness               -0.072205  0.072516       0.147944       1.000000
# Insulin                     -0.133894  0.222479      -0.007185       0.533525
# BMI                         -0.006969  0.227460       0.286740       0.468604
# DiabetesPedigreeFunction    -0.039908  0.071894       0.028455       0.175107
# Age                          0.598020  0.269762       0.350188      -0.053869
# Outcome                      0.195180  0.471294       0.154092       0.094745
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.133894 -0.006969                 -0.039908
# ...

# %%
import seaborn as sns
f, ax = plt.subplots(figsize = (12,10))
sns.heatmap(df.corr(),
            annot = True,
            linecolor = 'r',
            linewidths = .5,
            fmt = '.1f',
            ax = ax);

# %% [markdown]
# # Dimensionality reduction

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Separate the features from the target column ('Outcome')
X = df.drop('Outcome', axis=1)
y = df['Outcome']

# %%
# Standardize the features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# Apply PCA
pca = PCA(n_components=2) # we are reducing to 2 principal components
X_pca = pca.fit_transform(X)

# %%
# Print the explained variance ratio
print('Explained variance ratio: ', pca.explained_variance_ratio_)
# Out:
# Explained variance ratio:  [0.26153728 0.21691186]

# %%
# Visualize the results
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y)
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.show()

# %% [markdown]
# # Visualizations for exploring data

# %%
#Univariate Analysis

import scipy.stats as stats
import matplotlib.pyplot as plt
# Plot histogram for the 'Glucose' column
plt.hist(df['Glucose'], bins=10, alpha=0.5)
plt.title('Histogram for Glucose')
plt.xlabel('Glucose')
plt.ylabel('Frequency')
plt.show()

# %%
#Bivariate Analysis
# Scatter plot for 'Glucose' and 'Insulin'
sns.scatterplot(x='Glucose', y='Insulin', data=df)
plt.title('Scatter plot of Glucose and Insulin')
plt.show()

# %%
#Multivariate Analysis
# Pair plot for 'Pregnancies', 'Glucose', 'BloodPressure', 'Insulin'
sns.pairplot(df[['Pregnancies', 'Glucose', 'BloodPressure', 'Insulin']])
plt.show()
# Out:
# C:\Users\1508\AppData\Local\anaconda30\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\1508\AppData\Local\anaconda30\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\1508\AppData\Local\anaconda30\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# # Identifying patterns and trends

# %%
#Cluster analysis

from sklearn.cluster import KMeans

# Separate the features from the target column ('Outcome')
X = df.drop('Outcome', axis=1)

# Apply K-means clustering
kmeans = KMeans(n_clusters=2, random_state=0)  # we are choosing 2 clusters
kmeans.fit(X)

# Print the cluster centers
print('Cluster centers: ', kmeans.cluster_centers_)
# Out:
# C:\Users\1508\AppData\Local\anaconda30\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\1508\AppData\Local\anaconda30\lib\site-packages\sklearn\cluster\_kmeans.py:1440: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=8.
#   warnings.warn(
# Cluster centers:  [[  3.53166987 140.67754319  72.17274472  31.65642994 229.91170825
#    35.28982726   0.55330518  33.01151631]
#  [  3.76402975 114.31507776  68.07910751  17.15821501  27.53482082
#    31.10209601   0.4419121   33.11832319]]

# %%
# Scatter plot using column names
plt.scatter(X['Glucose'], X['Insulin'], c=kmeans.labels_, cmap='viridis')

# Plot the cluster centers
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red')
plt.title('Clusters of Patients')
plt.xlabel('Glucose')
plt.ylabel('Insulin')
plt.show()

# %% [markdown]
# # Auto EDA tools (pandas profiling and D-tale)

# %%
#D-tale
# !pip install dtale

# %%
import dtale
d = dtale.show(df)
d.open_browser()

# %%
#Pandas-profiling
# !pip install pandas-profiling
# Out:
# ...
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
#     WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
#     WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# ...

# %%
# Install or upgrade pandas-profiling
# !pip install --upgrade pandas-profiling

# Install pydantic-settings
# !pip install pydantic-settings
# Out:
# ...
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# ...

# %%
# !pip install pydantic-settings
# Out:
# ...
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# ...

# %%
# !pip install ydata-profiling==4.0.0
# Out:
# ...
#      ------------------------------------ 344.5/344.5 kB 629.5 kB/s eta 0:00:00
# ...
#   Using cached pydantic-1.10.13-cp310-cp310-win_amd64.whl (2.1 MB)
# ...
#      ---------------------------------------- 62.8/62.8 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 10.4/10.4 MB 3.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 40.1/40.1 MB 3.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.2/7.2 MB 3.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.1.5
#     Uninstalling typeguard-4.1.5:
#       Successfully uninstalled typeguard-4.1.5
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.3
#     Uninstalling scipy-1.11.3:
#       Successfully uninstalled scipy-1.11.3
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# ...

# %%
#importing required packages
import pandas_profiling
from pydantic_settings import BaseSettings
from ydata_profiling import ProfileReport

#descriptive statistics
ProfileReport(df)
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# Cell In[39], line 2
#       1 #importing required packages
# ----> 2 import pandas_profiling
#       3 from pydantic_settings import BaseSettings
#       4 from ydata_profiling import ProfileReport
#
# File ~\AppData\Local\anaconda30\lib\site-packages\pandas_profiling\__init__.py:8
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
#       6 from warnings import warn
# ----> 8 from pandas_profiling.compare_reports import compare
#       9 from pandas_profiling.controller import pandas_decorator
#      10 from pandas_profiling.profile_report import ProfileReport
#
# File ~\AppData\Local\anaconda30\lib\site-packages\pandas_profiling\compare_reports.py:6
#       2 from typing import Any, List, Optional, Tuple, Union
#       4 import pandas as pd
# ...
